# %%
import pandas as pd

# %%
dtype_options = {'column_name1': str, 'column_name2': str, 'column_name3': str}
df=pd.read_csv(r'C:\Users\Administrator\Downloads\iot_telemetry_data.csv',dtype=dtype_options, low_memory=False)

# %%
df
# Out:
#                   ts             device        co   humidity  light       lpg  \
# 0       1.590000e+09  b8:27:eb:bf:9d:51  0.004956  51.000000  False  0.007651
# 1       1.590000e+09  00:0f:00:70:91:0a  0.002840  76.000000  False  0.005114
# 2       1.590000e+09  b8:27:eb:bf:9d:51  0.004976  50.900000  False  0.007673
# 3       1.590000e+09  1c:bf:ce:15:ec:4d  0.004403  76.800003   True  0.007023
# 4       1.590000e+09  b8:27:eb:bf:9d:51  0.004967  50.900000  False  0.007664
# ...              ...                ...       ...        ...    ...       ...
# 405179           NaN                NaN       NaN        NaN    NaN       NaN
# 405180           NaN                NaN       NaN        NaN    NaN       NaN
# 405181           NaN                NaN       NaN        NaN    NaN       NaN
# 405182           NaN                NaN       NaN        NaN    NaN       NaN
# 405183           NaN                NaN       NaN        NaN    NaN       NaN
#
# ...

# %%
df.describe()
# Out:
#                  ts            co      humidity           lpg         smoke  \
# count  9.953500e+04  99535.000000  99535.000000  99535.000000  99535.000000
# mean   1.590000e+09      0.004680     60.921885      0.007302      0.019438
# std    0.000000e+00      0.001139     11.019916      0.001231      0.003525
# min    1.590000e+09      0.002264      6.900000      0.004341      0.011142
# 25%    1.590000e+09      0.004132     51.200000      0.006708      0.017736
# 50%    1.590000e+09      0.004833     55.200000      0.007513      0.020020
# 75%    1.590000e+09      0.005114     74.300003      0.007826      0.020912
# max    1.590000e+09      0.014420     79.300003      0.016567      0.046590
#
#                temp
# count  99535.000000
# mean      22.123851
# std        2.468794
# min        0.100000
# 25%       19.700001
# 50%       21.900000
# 75%       23.600000
# max       28.600000

# %%
df.columns
# Out:
# Index(['ts', 'device', 'co', 'humidity', 'light', 'lpg', 'motion', 'smoke',
#        'temp'],
#       dtype='object')

# %%
columns_rename={'ts':'timestamp','device':'device_id','co':'carbon_monoxide','humidity':'humidity'
                ,'light':'light','lpg':'liquefied_petroleum_gas','motion':'motion','smoke':'smoke','temp':'temperature'}

# %%
df=df.rename(columns=columns_rename)

# %%
df
# Out:
#            timestamp          device_id  carbon_monoxide   humidity  light  \
# 0       1.590000e+09  b8:27:eb:bf:9d:51         0.004956  51.000000  False
# 1       1.590000e+09  00:0f:00:70:91:0a         0.002840  76.000000  False
# 2       1.590000e+09  b8:27:eb:bf:9d:51         0.004976  50.900000  False
# 3       1.590000e+09  1c:bf:ce:15:ec:4d         0.004403  76.800003   True
# 4       1.590000e+09  b8:27:eb:bf:9d:51         0.004967  50.900000  False
# ...              ...                ...              ...        ...    ...
# 405179           NaN                NaN              NaN        NaN    NaN
# 405180           NaN                NaN              NaN        NaN    NaN
# 405181           NaN                NaN              NaN        NaN    NaN
# 405182           NaN                NaN              NaN        NaN    NaN
# 405183           NaN                NaN              NaN        NaN    NaN
#
#         liquefied_petroleum_gas motion     smoke  temperature
# ...

# %%
df=df.isnull().sum()       # find null values
df
# Out:
# timestamp                  305649
# device_id                  305649
# carbon_monoxide            305649
# humidity                   305649
# light                      305649
# liquefied_petroleum_gas    305649
# motion                     305649
# smoke                      305649
# temperature                305649
# dtype: int64

# %%
df=df.drop_duplicates()         # drop duplicates

# %%
df=df.dropna()           # drop null values

# %%
df.dtypes # dtypes
# Out:
# dtype('int64')

# %%
df['timestamp'] = df['timestamp'].astype('datetime64[ns]')   # data type changing

# %%
df['light']=df['light'].astype('bool')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'light'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['motion']=df['motion'].astype('bool')

# %%
df=df.to_csv("cleaned_dataset.csv")      # load the csv file
